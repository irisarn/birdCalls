# %%
# Dependencies
# ----------------------------------
import pandas as pd
from numpy import genfromtxt
from time import time
from datetime import datetime
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker, Session

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float, Date

# %% [markdown]
# # Create Database

# %%
#Load csv file
birdData_file = "data/birdData.csv"

# %%
# read and display csv with Pandas
birdData_file_df = pd.read_csv(birdData_file, index_col=0)
# birdData_file_df = birdData_file_df.rename(columns = {'City':'ID'})
birdData_file_df.head()
# Out:
#        id    English Name   Genus  \
# 0   92020    Canada Goose  Branta
# 1  530562  Cackling Goose  Branta
# 2  530560  Cackling Goose  Branta
# 3  530316  Cackling Goose  Branta
# 4  477242  Cackling Goose  Branta
#
#                                             Location  Latitude  Longitude  \
# 0               Sauvie Island, Multnomah Co., Oregon   45.6820  -122.8090
# 1  NW Reeder Rd, Canal, Access, Sauvie Island, Mu...   45.7020  -122.7810
# 2  NW Reeder Rd, Canal, Access, Sauvie Island, Mu...   45.7020  -122.7810
# 3  NW Oak Island Rd, Sauvie Island, Multnomah Cou...   45.6989  -122.8352
# 4  William Finley NWR, Bruce Rd Marsh, Willamette...   44.3897  -123.2960
#
#   Quality Score                                     Author Remarks  \
# 0             A  natural vocalization; calls from flock of 50 o...
# 1      no score                                                NaN
# 2      no score                                                NaN
# ...

# %%
birdMetadata_df = birdData_file_df[['id', 'English Name', 'Genus', 'Location', 'Latitude', 'Longitude']]
birdMetadata_df
# Out:
#          id    English Name       Genus  \
# 0     92020    Canada Goose      Branta
# 1    530562  Cackling Goose      Branta
# 2    530560  Cackling Goose      Branta
# 3    530316  Cackling Goose      Branta
# 4    477242  Cackling Goose      Branta
# ..      ...             ...         ...
# 495  534244    Purple Finch  Haemorhous
# 496  534243    Purple Finch  Haemorhous
# 497  371627    Purple Finch  Haemorhous
# 498  436813  Cassin's Finch  Haemorhous
# 499  436812  Cassin's Finch  Haemorhous
#
#                                               Location  Latitude  Longitude
# 0                 Sauvie Island, Multnomah Co., Oregon   45.6820  -122.8090
# 1    NW Reeder Rd, Canal, Access, Sauvie Island, Mu...   45.7020  -122.7810
# 2    NW Reeder Rd, Canal, Access, Sauvie Island, Mu...   45.7020  -122.7810
# 3    NW Oak Island Rd, Sauvie Island, Multnomah Cou...   45.6989  -122.8352
# 4    William Finley NWR, Bruce Rd Marsh, Willamette...   44.3897  -123.2960
# ...

# %%
birdUniquenames = birdData_file_df['English Name'].unique()
birdUniquenames
# Out:
# array(['Canada Goose', 'Cackling Goose', 'Snow Goose',
#        'Tundra Bean Goose', 'Tundra Swan', 'Wood Duck',
#        'Northern Shoveler', 'Gadwall', 'American Wigeon', 'Redhead',
#        'Ruddy Duck', 'California Quail', 'Spruce Grouse', 'Sooty Grouse',
#        'Horned Grebe', "Clark's Grebe", 'American White Pelican',
#        'Western Osprey', 'Sharp-shinned Hawk', "Cooper's Hawk",
#        'Bald Eagle', 'Red-shouldered Hawk', 'Red-tailed Hawk',
#        'Yellow Rail', 'Virginia Rail', 'Sandhill Crane',
#        'Black-necked Stilt', 'Pacific Golden Plover', 'Killdeer',
#        'Black Turnstone', 'Surfbird', "Baird's Sandpiper",
#        'Least Sandpiper', 'Pectoral Sandpiper', 'Western Sandpiper',
#        "Wilson's Snipe", 'Spotted Sandpiper', 'Willet',
#        'Greater Yellowlegs', 'Glaucous-winged Gull', 'Black Tern',
#        'Common Murre', 'Band-tailed Pigeon', 'Eurasian Collared Dove',
#        'Flammulated Owl', 'Great Horned Owl', 'Barred Owl',
# ...

# %%
birdUniquenames_df = pd.DataFrame()

# %%
birdUniquenames_df['uniqueName'] = birdUniquenames
birdUniquenames_df
# Out:
#              uniqueName
# 0          Canada Goose
# 1        Cackling Goose
# 2            Snow Goose
# 3     Tundra Bean Goose
# 4           Tundra Swan
# ..                  ...
# 112      American Robin
# 113  Buff-bellied Pipit
# 114    Evening Grosbeak
# 115        Purple Finch
# 116      Cassin's Finch
#
# [117 rows x 1 columns]

# %%
birdUniquenames_df = birdUniquenames_df.sort_values(by=['uniqueName'])

# %%
imageLocation = []

# %%
birdUniquenames_df['imageLocation'] = pd.Series(imageLocation)
birdUniquenames_df
# Out:
# c:\users\zinil\anaconda3\envs\myenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
#                   uniqueName  imageLocation
# 54          Acorn Woodpecker            NaN
# 93          American Bushtit            NaN
# 92    American Cliff Swallow            NaN
# 80             American Crow            NaN
# 71  American Grey Flycatcher            NaN
# ..                       ...            ...
# 35            Wilson's Snipe            NaN
# 5                  Wood Duck            NaN
# 94                   Wrentit            NaN
# 23               Yellow Rail            NaN
# 56  Yellow-bellied Sapsucker            NaN
#
# [117 rows x 2 columns]

# %%
birdGenus_df = birdData_file_df['Genus'].unique()
birdGenus_df
# Out:
# array(['Branta', 'Anser', 'Cygnus', 'Aix', 'Spatula', 'Mareca', 'Aythya',
#        'Oxyura', 'Callipepla', 'Falcipennis', 'Dendragapus', 'Podiceps',
#        'Aechmophorus', 'Pelecanus', 'Pandion', 'Accipiter', 'Haliaeetus',
#        'Buteo', 'Coturnicops', 'Rallus', 'Antigone', 'Himantopus',
#        'Pluvialis', 'Charadrius', 'Arenaria', 'Calidris', 'Gallinago',
#        'Actitis', 'Tringa', 'Larus', 'Chlidonias', 'Uria', 'Patagioenas',
#        'Streptopelia', 'Psiloscops', 'Bubo', 'Strix', 'Glaucidium',
#        'Aegolius', 'Chaetura', 'Calypte', 'Selasphorus', 'Megaceryle',
#        'Melanerpes', 'Sphyrapicus', 'Picoides', 'Dryobates', 'Colaptes',
#        'Dryocopus', 'Falco', 'Melopsittacus', 'Sayornis', 'Contopus',
#        'Empidonax', 'Myiarchus', 'Vireo', 'Cyanocitta', 'Aphelocoma',
#        'Corvus', 'Bombycilla', 'Phainopepla', 'Baeolophus', 'Poecile',
#        'Alauda', 'Tachycineta', 'Hirundo', 'Petrochelidon',
# ...

# %%
birdGenus_df = birdData_file_df['Genus'].nunique()
birdGenus_df
# Out:
# 86

# %%
birdRecordings_df = birdData_file_df[['id','Recording Type', 'Quality Score', 'Author Remarks', 'MP3 Download URL', 'Recording Name']]
birdRecordings_df
# Out:
#          id       Recording Type Quality Score  \
# 0     92020                 call             A
# 1    530562                 call      no score
# 2    530560                 call      no score
# 3    530316                 call      no score
# 4    477242                 call      no score
# ..      ...                  ...           ...
# 495  534244  adult, female, song      no score
# 496  534243  adult, female, song      no score
# 497  371627         female, song             C
# 498  436813                 song      no score
# 499  436812                 song             A
#
#                                         Author Remarks  \
# 0    natural vocalization; calls from flock of 50 o...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4               Recording amplified. High pass filter.
# ..                                                 ...
# ...

# %%
# Sets an object to utilize the default declarative base
Base = declarative_base()

# %%
# Creates Classes which will serve as the anchor points for our Tables
class birdMetadata(Base):
    __tablename__ = 'metadata'
    id = Column(Integer, primary_key=True)
    english_name = Column(String(40))
    genus = Column(String(20))
    location = Column(String(60))
    latitude = Column(Float)
    longitude = Column(Float)

# %%
class birdRecordings(Base):
    __tablename__ = 'recordings'
    id = Column(Integer, primary_key=True)
    type = Column(String(40))
    quality_score = Column(String(20))
    author_remarks = Column(String(100))
    download = Column(String(50))
    recording_name = Column(String(50))

# %%
class birdUniquenames(Base):
    __tablename__ = 'uniqueNames'
    id = Column(Integer, primary_key=True)
    unique_name = Column(String(40))
    imageLocation = Column(String(100))

# %%
if __name__ == "__main__":
    t = time()

    #Create the database
    engine = create_engine('sqlite:///data/birdDB.sqlite')
    Base.metadata.create_all(engine)

# %%
session = Session(bind=engine)

# %%
birdMetadata_df.to_sql("metadata",
                      engine,
                      if_exists='replace',
                      index=False,
                      chunksize=500,
                      dtype={"id": Integer,
                             "english_name": String(40),
                             "genus": String(20),
                             "location": String(60),
                             "latitude": Float,
                             "longitude": Float
                            })

# %%
engine.execute("SELECT * FROM metadata").fetchall()
# Out:
# [(92020, 'Canada Goose', 'Branta', 'Sauvie Island, Multnomah Co., Oregon', 45.681999999999995, -122.809),
#  (530562, 'Cackling Goose', 'Branta', 'NW Reeder Rd, Canal, Access, Sauvie Island, Multnomah County, Oregon', 45.702, -122.781),
#  (530560, 'Cackling Goose', 'Branta', 'NW Reeder Rd, Canal, Access, Sauvie Island, Multnomah County, Oregon', 45.702, -122.781),
#  (530316, 'Cackling Goose', 'Branta', 'NW Oak Island Rd, Sauvie Island, Multnomah County, Oregon', 45.6989, -122.8352),
#  (477242, 'Cackling Goose', 'Branta', 'William Finley NWR, Bruce Rd Marsh, Willamette Valley (near  Corvallis), Benton County, Oregon', 44.3897, -123.296),
#  (477241, 'Cackling Goose', 'Branta', 'William Finley NWR, Bruce Rd Fields, Willamette Valley (near  Corvallis), Benton County, Oregon', 44.3895, -123.3159),
#  (477240, 'Cackling Goose', 'Branta', 'William Finley NWR, Bruce Rd Marsh, Willamette Valley (near  Corvallis), Benton County, Oregon', 44.3897, -123.296),
# ...

# %%
birdRecordings_df.to_sql("recordings",
                          engine,
                          if_exists='replace',
                          index=False,
                          chunksize=500,
                          dtype={"id": Integer,
                                 "type": String(40),
                                 "quality_score": String(20),
                                 "author_remarks": String(100),
                                 "download": String(50),
                                 "recording_name": String(50)
                                  })

# %%
engine.execute("SELECT * FROM recordings").fetchall()
# Out:
# [(92020, 'call', 'A', 'natural vocalization; calls from flock of 50 or so birds, some of which had red neck rings.', '//www.xeno-canto.org/92020/download', '92020.mp3'),
#  (530562, 'call', 'no score', None, '//www.xeno-canto.org/530562/download', '530562.mp3'),
#  (530560, 'call', 'no score', None, '//www.xeno-canto.org/530560/download', '530560.mp3'),
#  (530316, 'call', 'no score', None, '//www.xeno-canto.org/530316/download', '530316.mp3'),
#  (477242, 'call', 'no score', 'Recording amplified. High pass filter.', '//www.xeno-canto.org/477242/download', '477242.mp3'),
#  (477241, 'call', 'no score', 'Recording amplified. High pass filter.', '//www.xeno-canto.org/477241/download', '477241.mp3'),
#  (477240, 'call', 'no score', 'Recording amplified. High pass filter.', '//www.xeno-canto.org/477240/download', '477240.mp3'),
#  (477239, 'call', 'no score', 'Recording amplified. High pass filter.', '//www.xeno-canto.org/477239/download', '477239.mp3'),
# ...

# %%
birdUniquenames_df.to_sql("uniqueNames",
                          engine,
                          if_exists='replace',
                          index=False,
                          chunksize=500,
                          dtype={"id": Integer,
                                 "uniqueName": String(40),
                                 "imageLocation": String(100),
                                  })

# %%
engine.execute("SELECT * FROM uniqueNames").fetchall()
# Out:
# [(0, 'Acorn Woodpecker', './images\\acorn_woodpecker\\1651956c1e.jpg'),
#  (1, 'American Bushtit', './images\\american_bushtit\\23de54f7b6.jpg'),
#  (2, 'American Cliff Swallow', './images\\american_cliff_swallow\\4d50746d92.jpg'),
#  (3, 'American Crow', './images\\american_crow\\4aa703f5b0.jpg'),
#  (4, 'American Grey Flycatcher', './images\\american_grey_flycatcher\\bc34237459.jpg'),
#  (5, 'American Robin', './images\\american_robin\\ddd1ec93f3.jpg'),
#  (6, 'American White Pelican', './images\\american_white_pelican\\980d8366f1.jpg'),
#  (7, 'American Wigeon', './images\\american_wigeon\\9338a24a8a.jpg'),
#  (8, "Anna's Hummingbird", "./images\\anna's_hummingbird\\97d009eaf1.jpg"),
#  (9, 'Ash-throated Flycatcher', './images\\ash-throated_flycatcher\\2b63d3cdc5.jpg'),
#  (10, "Baird's Sandpiper", "./images\\baird's_sandpiper\\2de03d1f08.jpg"),
#  (11, 'Bald Eagle', './images\\bald_eagle\\6641578ebb.jpg'),
# ...
